# %%
# %sql
SELECT COUNT(*) FROM cust_order_delta;
DESCRIBE HISTORY cust_order_delta;
SELECT orderid, paymentvalue, is_active, start_date, end_date FROM orderpay_scd2_delta ORDER BY start_date LIMIT 20;
DESCRIBE HISTORY orderpay_scd2_delta;
